# %% [markdown]
# **<h1>MISC</h1>**

# %%
pip install vaderSentiment

# %%
pip install afinn

# %%
pip install textblob

# %%
pip install scikit-learn

# %% [markdown]
# **<h1>IMPORTS</h1>**

# %%
import random
import emoji
import pandas as pd
import numpy as np
import tensorflow as tf

from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from afinn import Afinn
from nltk.corpus import wordnet

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

from tensorflow.keras.utils import pad_sequences
from tensorflow.keras import layers, models
from tensorflow.keras.models import load_model

# %% [markdown]
# **<h1>DATASETS</h1>**

# %%
df = pd.read_csv('/kaggle/input/datasets/choonkhonng/malaysia-restaurant-review-datasets/Malaysia Restaurant Review Datasets/data_cleaned/TripAdvisor_data_cleaned.csv')
df.head(5)

# %%
df2.columns

# %%
df_new = pd.read_csv('/kaggle/input/datasets/choonkhonng/malaysia-restaurant-review-datasets/Malaysia Restaurant Review Datasets/data_cleaned/TripAdvisor_data_cleaned.csv',
                      usecols=['Title', 'Review', 'Restaurant'])
df_new.head(5)

# %%
df_clean = df_new.dropna()
print(len(df_clean))

# %%
regex = r'[^a-zA-Z0-9\s]'

df_clean['Review'] = df_clean['Review'].str.replace(regex, '', regex=True)

# %%
df_clean['Review'] = df_clean['Review'].apply(lambda text: ''.join(c for c in text if c not in emoji.EMOJI_DATA))

# %%
df_clean['Review'] = df_clean['Review'].str.strip()
df_clean['Review'] = df_clean['Review'].str.lower()

# %%
df_clean['Caption'][2]

# %%
df['Caption'][2]

# %% [markdown]
# **<h3>Labeling</h3>**

# %%
# TextBlob
def textblob_sentiment(text):
    blob = TextBlob(str(text))
    polarity = blob.sentiment.polarity
    if polarity >= 0:
        return 'positive'
    else:
        return 'negative'

# %%
# Vader
def vader_sentiment(text):
    scores = SentimentIntensityAnalyzer().polarity_scores(str(text))
    compound = scores['compound']
    if compound >= 0:
        return 'positive'
    else:
        return 'negative'

# %%
# AFINN
def afinn_sentiment(text):
    scores = Afinn().score(str(text))
    if scores >= 0:
        return 'positive'
    else:
        return 'negative'

# %%
df_clean['TextBlob_Label'] = df_clean['Review'].apply(textblob_sentiment)
df_clean['Vader_Label'] = df_clean['Review'].apply(vader_sentiment)
df_clean['Afinn_Label'] = df_clean['Review'].apply(afinn_sentiment)

# %%
print(df_clean['TextBlob_Label'].value_counts())
print(df_clean['Vader_Label'].value_counts())
print(df_clean['Afinn_Label'].value_counts())

# %%
df_clean.to_csv('/kaggle/working/sentiment_results.csv', index=False)

# %% [markdown]
# **<h3>Synonym Augmentation</h3>**

# %%
df = pd.read_csv('./sentiment_results.csv')
df.head(2)
# Out:
#                                     Title  \
# 0                  Chambers Bar and Grill
# 1  Always a pleasure. Place to celebrate.
#
#                                               Review      Restaurant  \
# 0  david thanga mikail and chef steven gave brill...  Chambers Grill
# 1  we visited for family celebration and as usual...  Chambers Grill
#
#   TextBlob_Label Vader_Label Afinn_Label
# 0       positive    positive    positive
# 1       positive    positive    positive

# %%
def synonym_replacement(sentence, n=1):
    words = sentence.split()
    new_words = words.copy()
    random_word_list = list(set(words))
    random.shuffle(random_word_list)
    
    num_replaced = 0
    for word in random_word_list:
        synonyms = wordnet.synsets(word)
        if synonyms:
            synonym_words = set()
            for syn in synonyms:
                for lemma in syn.lemmas():
                    synonym_words.add(lemma.name())
            synonym_words.discard(word)
            if synonym_words:
                synonym = random.choice(list(synonym_words))
                new_words = [synonym if w == word else w for w in new_words]
                num_replaced += 1
            if num_replaced >= n:
                break
    return " ".join(new_words)

# %%
def balance_sentiment(df, sentiment_col, text_col):
    counts = df[sentiment_col].value_counts()
    min_class = counts.idxmin()
    max_class = counts.idxmax()
    diff = counts[max_class] - counts[min_class]

    minority_df = df[df[sentiment_col] == min_class]

    augmented_rows = minority_df.sample(diff, replace=True).copy()
    augmented_rows[text_col] = augmented_rows[text_col].apply(lambda x: synonym_replacement(x, n=2))

    balanced_df = pd.concat([df, augmented_rows], ignore_index=True)
    return balanced_df

# %%
balanced_textblob = balance_sentiment(df, 'TextBlob_Label', 'Review')
balanced_vader = balance_sentiment(df, 'Vader_Label', 'Review')
balanced_afinn = balance_sentiment(df, 'Afinn_Label', 'Review')

# %%
print(balanced_textblob['TextBlob_Label'].value_counts())
print(balanced_vader['Vader_Label'].value_counts())
print(balanced_afinn['Afinn_Label'].value_counts())
# Out:
# TextBlob_Label
# positive    129887
# negative    129887
# Name: count, dtype: int64
# Vader_Label
# positive    130348
# negative    130348
# Name: count, dtype: int64
# Afinn_Label
# positive    132981
# negative    132981
# Name: count, dtype: int64

# %% [markdown]
# **<h1>TOKENIZATION</h1>**

# %%
vectorizer = CountVectorizer(max_features=5000)

# %%
# Bag of Words
tb_bow = balanced_textblob['Review'].astype(str).tolist()
vader_bow = balanced_vader['Review'].astype(str).tolist()
afinn_bow = balanced_afinn['Review'].astype(str).tolist()

# %%
X_tb_bow = vectorizer.fit_transform(tb_bow).toarray()
X_vader_bow = vectorizer.fit_transform(vader_bow).toarray()
X_afinn_bow = vectorizer.fit_transform(afinn_bow).toarray()

# %%
balanced_textblob['TextBlob_Label'] = balanced_textblob['TextBlob_Label'].replace({'positive': 1, 'negative': 0})
balanced_vader['Vader_Label'] = balanced_vader['Vader_Label'].replace({'positive': 1, 'negative': 0})
balanced_afinn['Afinn_Label'] = balanced_afinn['Afinn_Label'].replace({'positive': 1, 'negative': 0})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1268\3956780450.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balanced_textblob['TextBlob_Label'] = balanced_textblob['TextBlob_Label'].replace({'positive': 1, 'negative': 0})
# C:\Users\USER\AppData\Local\Temp\ipykernel_1268\3956780450.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balanced_vader['Vader_Label'] = balanced_vader['Vader_Label'].replace({'positive': 1, 'negative': 0})
# C:\Users\USER\AppData\Local\Temp\ipykernel_1268\3956780450.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balanced_afinn['Afinn_Label'] = balanced_afinn['Afinn_Label'].replace({'positive': 1, 'negative': 0})

# %%
y_tb_bow = LabelEncoder().fit_transform(balanced_textblob['TextBlob_Label'])
y_vader_bow = LabelEncoder().fit_transform(balanced_vader['Vader_Label'])
y_afinn_bow = LabelEncoder().fit_transform(balanced_afinn['Afinn_Label'])

# %%
X_tb_bow_seq = pad_sequences(X_tb_bow, maxlen=150, padding='post', truncating='post', value=0)
X_vader_bow_seq = pad_sequences(X_vader_bow, maxlen=150, padding='post', truncating='post', value=0)
X_afinn_bow_seq = pad_sequences(X_afinn_bow, maxlen=150, padding='post', truncating='post', value=0)

# %% [markdown]
# **<h1>TRAINING</h1>**

# %% [markdown]
# **<h3>CNN VADER</h3>**

# %%
model = models.Sequential([
    layers.Embedding(input_dim=5000, output_dim=100, input_length=150),
    layers.Conv1D(1024, 3, padding='valid', activation='relu', strides=1),
    layers.GlobalMaxPooling1D(),
    
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(2048, activation='relu'),
    
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(1, activation='sigmoid') 
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 100)          500000
#
#  conv1d (Conv1D)             (None, 148, 1024)         308224
#
#  global_max_pooling1d (Globa  (None, 1024)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense (Dense)               (None, 2048)              2099200
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 2,921,761
# Trainable params: 2,915,617
# Non-trainable params: 6,144
# _________________________________________________________________

# %%
model.fit(X_vader_bow_seq, y_vader_bow, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 6518/6518 [==============================] - 60s 8ms/step - loss: 0.7264 - accuracy: 0.5880 - val_loss: 1.0070 - val_accuracy: 0.0056
# Epoch 2/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6951 - accuracy: 0.6011 - val_loss: 0.9443 - val_accuracy: 0.0535
# Epoch 3/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6810 - accuracy: 0.6104 - val_loss: 1.0425 - val_accuracy: 0.0072
# Epoch 4/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6709 - accuracy: 0.6156 - val_loss: 1.0100 - val_accuracy: 0.0526
# Epoch 5/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6638 - accuracy: 0.6202 - val_loss: 0.9807 - val_accuracy: 0.0527
# Epoch 6/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6597 - accuracy: 0.6228 - val_loss: 1.0374 - val_accuracy: 0.0518
# Epoch 7/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6578 - accuracy: 0.6236 - val_loss: 0.9408 - val_accuracy: 0.0528
# Epoch 8/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6574 - accuracy: 0.6231 - val_loss: 0.9318 - val_accuracy: 0.0517
# Epoch 9/50
# 6518/6518 [==============================] - 54s 8ms/step - loss: 0.6573 - accuracy: 0.6243 - val_loss: 0.9353 - val_accuracy: 0.0530
# Epoch 10/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6575 - accuracy: 0.6237 - val_loss: 0.9704 - val_accuracy: 0.0530
# Epoch 11/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6248 - val_loss: 0.9832 - val_accuracy: 0.0475
# Epoch 12/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6241 - val_loss: 1.1149 - val_accuracy: 0.0517
# Epoch 13/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6252 - val_loss: 1.0007 - val_accuracy: 0.0530
# Epoch 14/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6571 - accuracy: 0.6249 - val_loss: 0.9005 - val_accuracy: 0.0531
# Epoch 15/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6247 - val_loss: 1.0365 - val_accuracy: 0.0521
# Epoch 16/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6240 - val_loss: 0.9497 - val_accuracy: 0.0531
# Epoch 17/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6240 - val_loss: 1.0005 - val_accuracy: 0.0517
# Epoch 18/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6574 - accuracy: 0.6244 - val_loss: 0.9934 - val_accuracy: 0.0517
# Epoch 19/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6575 - accuracy: 0.6241 - val_loss: 1.0887 - val_accuracy: 0.0518
# Epoch 20/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6245 - val_loss: 0.9742 - val_accuracy: 0.0521
# Epoch 21/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6248 - val_loss: 0.9552 - val_accuracy: 0.0522
# Epoch 22/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6575 - accuracy: 0.6243 - val_loss: 1.0416 - val_accuracy: 0.0515
# Epoch 23/50
# 6518/6518 [==============================] - 53s 8ms/step - loss: 0.6575 - accuracy: 0.6243 - val_loss: 1.0420 - val_accuracy: 0.0513
# Epoch 24/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6575 - accuracy: 0.6245 - val_loss: 0.9289 - val_accuracy: 0.0597
# Epoch 25/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6246 - val_loss: 1.0187 - val_accuracy: 0.0522
# Epoch 26/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6574 - accuracy: 0.6237 - val_loss: 1.0711 - val_accuracy: 0.0133
# Epoch 27/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6578 - accuracy: 0.6235 - val_loss: 0.9873 - val_accuracy: 0.0531
# Epoch 28/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6575 - accuracy: 0.6242 - val_loss: 1.0535 - val_accuracy: 0.0521
# Epoch 29/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6574 - accuracy: 0.6246 - val_loss: 0.9565 - val_accuracy: 0.0650
# Epoch 30/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6248 - val_loss: 1.0546 - val_accuracy: 0.0527
# Epoch 31/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6245 - val_loss: 1.0179 - val_accuracy: 0.0527
# Epoch 32/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6252 - val_loss: 0.9159 - val_accuracy: 0.0651
# Epoch 33/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6248 - val_loss: 0.9960 - val_accuracy: 0.0528
# Epoch 34/50
# 6518/6518 [==============================] - 53s 8ms/step - loss: 0.6573 - accuracy: 0.6248 - val_loss: 1.1546 - val_accuracy: 0.0444
# Epoch 35/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6243 - val_loss: 1.0122 - val_accuracy: 0.0496
# Epoch 36/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6248 - val_loss: 0.9244 - val_accuracy: 0.0526
# Epoch 37/50
# 6518/6518 [==============================] - 53s 8ms/step - loss: 0.6574 - accuracy: 0.6252 - val_loss: 0.9882 - val_accuracy: 0.0528
# Epoch 38/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6246 - val_loss: 1.0630 - val_accuracy: 0.0496
# Epoch 39/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6249 - val_loss: 1.1280 - val_accuracy: 0.0512
# Epoch 40/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6246 - val_loss: 0.8727 - val_accuracy: 0.0652
# Epoch 41/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6246 - val_loss: 0.9820 - val_accuracy: 0.0530
# Epoch 42/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6251 - val_loss: 0.9591 - val_accuracy: 0.0530
# Epoch 43/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6249 - val_loss: 1.0425 - val_accuracy: 0.0511
# Epoch 44/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6575 - accuracy: 0.6246 - val_loss: 1.0083 - val_accuracy: 0.0519
# Epoch 45/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6249 - val_loss: 1.0656 - val_accuracy: 0.0506
# Epoch 46/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6246 - val_loss: 0.9601 - val_accuracy: 0.0474
# Epoch 47/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6573 - accuracy: 0.6252 - val_loss: 0.9577 - val_accuracy: 0.0522
# Epoch 48/50
# 6518/6518 [==============================] - 52s 8ms/step - loss: 0.6572 - accuracy: 0.6254 - val_loss: 1.0881 - val_accuracy: 0.0521
# Epoch 49/50
# 6518/6518 [==============================] - 53s 8ms/step - loss: 0.6572 - accuracy: 0.6261 - val_loss: 1.0332 - val_accuracy: 0.0518
# Epoch 50/50
# 6518/6518 [==============================] - 53s 8ms/step - loss: 0.6575 - accuracy: 0.6248 - val_loss: 0.9462 - val_accuracy: 0.0528

# %%
model.save('./demo/cnn_vader_bow_50.keras')

# %%
loaded_model = load_model('./demo/cnn_vader_bow_50.keras')

# %% [markdown]
# **<h3>CNN AFINN</h3>**

# %%
model_afinn = models.Sequential([
    layers.Embedding(input_dim=5000, output_dim=100, input_length=150),
    layers.Conv1D(1024, 3, padding='valid', activation='relu', strides=1),
    layers.GlobalMaxPooling1D(),
    
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(2048, activation='relu'),
    
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(1, activation='sigmoid') 
])

# %%
model_afinn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_afinn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 100)          500000
#
#  conv1d (Conv1D)             (None, 148, 1024)         308224
#
#  global_max_pooling1d (Globa  (None, 1024)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense (Dense)               (None, 2048)              2099200
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 2,921,761
# Trainable params: 2,915,617
# Non-trainable params: 6,144
# _________________________________________________________________

# %%
model_afinn.fit(X_afinn_bow_seq, y_afinn_bow, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 6650/6650 [==============================] - 61s 8ms/step - loss: 0.7198 - accuracy: 0.5944 - val_loss: 0.9680 - val_accuracy: 0.0732
# Epoch 2/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6892 - accuracy: 0.6078 - val_loss: 0.9831 - val_accuracy: 0.0430
# Epoch 3/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6759 - accuracy: 0.6159 - val_loss: 0.9396 - val_accuracy: 0.4315
# Epoch 4/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6659 - accuracy: 0.6212 - val_loss: 0.9578 - val_accuracy: 0.0615
# Epoch 5/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6589 - accuracy: 0.6252 - val_loss: 1.0081 - val_accuracy: 0.0615
# Epoch 6/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6549 - accuracy: 0.6268 - val_loss: 0.9974 - val_accuracy: 0.0597
# Epoch 7/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6532 - accuracy: 0.6282 - val_loss: 1.0554 - val_accuracy: 0.0599
# Epoch 8/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6529 - accuracy: 0.6277 - val_loss: 1.0044 - val_accuracy: 0.0617
# Epoch 9/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6526 - accuracy: 0.6284 - val_loss: 0.9011 - val_accuracy: 0.0617
# Epoch 10/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6528 - accuracy: 0.6281 - val_loss: 0.9462 - val_accuracy: 0.0628
# Epoch 11/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6285 - val_loss: 1.0146 - val_accuracy: 0.0615
# Epoch 12/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6524 - accuracy: 0.6289 - val_loss: 0.9248 - val_accuracy: 0.0640
# Epoch 13/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6284 - val_loss: 0.9154 - val_accuracy: 0.0615
# Epoch 14/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6526 - accuracy: 0.6287 - val_loss: 0.9838 - val_accuracy: 0.0640
# Epoch 15/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6286 - val_loss: 0.9435 - val_accuracy: 0.0683
# Epoch 16/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6287 - val_loss: 1.0655 - val_accuracy: 0.0640
# Epoch 17/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6287 - val_loss: 0.8906 - val_accuracy: 0.0761
# Epoch 18/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6524 - accuracy: 0.6289 - val_loss: 0.9100 - val_accuracy: 0.0683
# Epoch 19/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6527 - accuracy: 0.6289 - val_loss: 1.0418 - val_accuracy: 0.0683
# Epoch 20/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6526 - accuracy: 0.6291 - val_loss: 1.0062 - val_accuracy: 0.0683
# Epoch 21/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6526 - accuracy: 0.6288 - val_loss: 1.0992 - val_accuracy: 0.0640
# Epoch 22/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6523 - accuracy: 0.6299 - val_loss: 0.9247 - val_accuracy: 0.0761
# Epoch 23/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6525 - accuracy: 0.6293 - val_loss: 0.9722 - val_accuracy: 0.0631
# Epoch 24/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6524 - accuracy: 0.6295 - val_loss: 0.9414 - val_accuracy: 0.0627
# Epoch 25/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6286 - val_loss: 0.9705 - val_accuracy: 0.0640
# Epoch 26/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6524 - accuracy: 0.6294 - val_loss: 0.9589 - val_accuracy: 0.0627
# Epoch 27/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6527 - accuracy: 0.6287 - val_loss: 0.8865 - val_accuracy: 0.0760
# Epoch 28/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6522 - accuracy: 0.6295 - val_loss: 0.8975 - val_accuracy: 0.0761
# Epoch 29/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6523 - accuracy: 0.6292 - val_loss: 1.0259 - val_accuracy: 0.0683
# Epoch 30/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6523 - accuracy: 0.6290 - val_loss: 0.9651 - val_accuracy: 0.0683
# Epoch 31/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6528 - accuracy: 0.6292 - val_loss: 0.8906 - val_accuracy: 0.4188
# Epoch 32/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6526 - accuracy: 0.6289 - val_loss: 0.9127 - val_accuracy: 0.0683
# Epoch 33/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6289 - val_loss: 0.9468 - val_accuracy: 0.0683
# Epoch 34/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6525 - accuracy: 0.6293 - val_loss: 0.9251 - val_accuracy: 0.0760
# Epoch 35/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6527 - accuracy: 0.6289 - val_loss: 1.0083 - val_accuracy: 0.0682
# Epoch 36/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6526 - accuracy: 0.6290 - val_loss: 0.9766 - val_accuracy: 0.0683
# Epoch 37/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6527 - accuracy: 0.6286 - val_loss: 1.0370 - val_accuracy: 0.0626
# Epoch 38/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6528 - accuracy: 0.6295 - val_loss: 1.0180 - val_accuracy: 0.0617
# Epoch 39/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6526 - accuracy: 0.6292 - val_loss: 1.0016 - val_accuracy: 0.0629
# Epoch 40/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6527 - accuracy: 0.6293 - val_loss: 0.9452 - val_accuracy: 0.0759
# Epoch 41/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6526 - accuracy: 0.6290 - val_loss: 1.0536 - val_accuracy: 0.0633
# Epoch 42/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6526 - accuracy: 0.6291 - val_loss: 0.9936 - val_accuracy: 0.0680
# Epoch 43/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6527 - accuracy: 0.6299 - val_loss: 0.9329 - val_accuracy: 0.0754
# Epoch 44/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6529 - accuracy: 0.6296 - val_loss: 0.9169 - val_accuracy: 0.0680
# Epoch 45/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6531 - accuracy: 0.6291 - val_loss: 0.9896 - val_accuracy: 0.0609
# Epoch 46/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6528 - accuracy: 0.6296 - val_loss: 0.9967 - val_accuracy: 0.0625
# Epoch 47/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6528 - accuracy: 0.6292 - val_loss: 1.0512 - val_accuracy: 0.0625
# Epoch 48/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6529 - accuracy: 0.6295 - val_loss: 1.0036 - val_accuracy: 0.0617
# Epoch 49/50
# 6650/6650 [==============================] - 53s 8ms/step - loss: 0.6526 - accuracy: 0.6303 - val_loss: 0.9076 - val_accuracy: 0.0625
# Epoch 50/50
# 6650/6650 [==============================] - 52s 8ms/step - loss: 0.6528 - accuracy: 0.6293 - val_loss: 0.9431 - val_accuracy: 0.0628

# %%
model_afinn.save('./demo/cnn_afinn_bow_50.keras')

# %%
loaded_model = load_model('./demo/cnn_afinn_bow_50.keras')

# %% [markdown]
# **<h3>CNN TEXTBLOB</h3>**

# %%
model_tb = models.Sequential([
    layers.Embedding(input_dim=5000, output_dim=100, input_length=150),
    layers.Conv1D(1024, 3, padding='valid', activation='relu', strides=1),
    layers.GlobalMaxPooling1D(),
    
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(2048, activation='relu'),
    
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(1, activation='sigmoid') 
])

# %%
model_tb.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_tb.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 100)          500000
#
#  conv1d (Conv1D)             (None, 148, 1024)         308224
#
#  global_max_pooling1d (Globa  (None, 1024)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense (Dense)               (None, 2048)              2099200
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 2,921,761
# Trainable params: 2,915,617
# Non-trainable params: 6,144
# _________________________________________________________________

# %%
model_tb.fit(X_tb_bow_seq, y_tb_bow, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 6495/6495 [==============================] - 60s 8ms/step - loss: 0.7286 - accuracy: 0.5823 - val_loss: 1.0365 - val_accuracy: 0.0481
# Epoch 2/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6971 - accuracy: 0.5970 - val_loss: 1.0913 - val_accuracy: 0.0471
# Epoch 3/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6845 - accuracy: 0.6048 - val_loss: 1.0151 - val_accuracy: 0.0475
# Epoch 4/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6737 - accuracy: 0.6134 - val_loss: 1.1014 - val_accuracy: 0.0363
# Epoch 5/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6674 - accuracy: 0.6170 - val_loss: 1.0208 - val_accuracy: 0.0445
# Epoch 6/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6628 - accuracy: 0.6209 - val_loss: 1.0153 - val_accuracy: 0.0471
# Epoch 7/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6608 - accuracy: 0.6223 - val_loss: 0.9227 - val_accuracy: 0.0481
# Epoch 8/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6602 - accuracy: 0.6241 - val_loss: 0.9449 - val_accuracy: 0.0481
# Epoch 9/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6599 - accuracy: 0.6234 - val_loss: 0.9351 - val_accuracy: 0.0481
# Epoch 10/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6600 - accuracy: 0.6238 - val_loss: 1.1180 - val_accuracy: 0.0470
# Epoch 11/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6601 - accuracy: 0.6242 - val_loss: 1.0258 - val_accuracy: 0.0480
# Epoch 12/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6599 - accuracy: 0.6240 - val_loss: 0.9110 - val_accuracy: 0.0481
# Epoch 13/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6600 - accuracy: 0.6232 - val_loss: 1.0187 - val_accuracy: 0.0481
# Epoch 14/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6599 - accuracy: 0.6234 - val_loss: 0.9546 - val_accuracy: 0.0481
# Epoch 15/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6601 - accuracy: 0.6239 - val_loss: 0.9638 - val_accuracy: 0.0481
# Epoch 16/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6599 - accuracy: 0.6243 - val_loss: 1.0155 - val_accuracy: 0.0479
# Epoch 17/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6601 - accuracy: 0.6232 - val_loss: 1.0926 - val_accuracy: 0.0479
# Epoch 18/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6600 - accuracy: 0.6242 - val_loss: 1.0313 - val_accuracy: 0.0471
# Epoch 19/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6600 - accuracy: 0.6237 - val_loss: 1.0217 - val_accuracy: 0.0480
# Epoch 20/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6600 - accuracy: 0.6239 - val_loss: 1.0507 - val_accuracy: 0.0470
# Epoch 21/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6600 - accuracy: 0.6240 - val_loss: 0.9770 - val_accuracy: 0.0481
# Epoch 22/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6603 - accuracy: 0.6232 - val_loss: 0.9857 - val_accuracy: 0.0479
# Epoch 23/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6601 - accuracy: 0.6234 - val_loss: 1.0319 - val_accuracy: 0.0470
# Epoch 24/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6601 - accuracy: 0.6235 - val_loss: 0.9512 - val_accuracy: 0.0480
# Epoch 25/50
# 6495/6495 [==============================] - 53s 8ms/step - loss: 0.6601 - accuracy: 0.6237 - val_loss: 1.1244 - val_accuracy: 0.0441
# Epoch 26/50
# 6495/6495 [==============================] - 53s 8ms/step - loss: 0.6601 - accuracy: 0.6233 - val_loss: 0.9809 - val_accuracy: 0.0481
# Epoch 27/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6598 - accuracy: 0.6241 - val_loss: 0.9625 - val_accuracy: 0.0479
# Epoch 28/50
# 6495/6495 [==============================] - 53s 8ms/step - loss: 0.6600 - accuracy: 0.6239 - val_loss: 0.9523 - val_accuracy: 0.0479
# Epoch 29/50
# 6495/6495 [==============================] - 53s 8ms/step - loss: 0.6601 - accuracy: 0.6242 - val_loss: 1.0136 - val_accuracy: 0.0479
# Epoch 30/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6599 - accuracy: 0.6241 - val_loss: 1.0009 - val_accuracy: 0.0481
# Epoch 31/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6600 - accuracy: 0.6238 - val_loss: 1.0654 - val_accuracy: 0.0479
# Epoch 32/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6601 - accuracy: 0.6237 - val_loss: 0.9048 - val_accuracy: 0.0479
# Epoch 33/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6599 - accuracy: 0.6238 - val_loss: 0.9554 - val_accuracy: 0.0480
# Epoch 34/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6599 - accuracy: 0.6244 - val_loss: 1.0056 - val_accuracy: 0.0481
# Epoch 35/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6600 - accuracy: 0.6235 - val_loss: 0.9971 - val_accuracy: 0.0481
# Epoch 36/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6600 - accuracy: 0.6243 - val_loss: 0.9433 - val_accuracy: 0.0479
# Epoch 37/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6599 - accuracy: 0.6240 - val_loss: 1.0111 - val_accuracy: 0.0443
# Epoch 38/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6598 - accuracy: 0.6242 - val_loss: 1.0085 - val_accuracy: 0.0479
# Epoch 39/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6601 - accuracy: 0.6241 - val_loss: 0.9845 - val_accuracy: 0.0481
# Epoch 40/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6600 - accuracy: 0.6244 - val_loss: 0.9959 - val_accuracy: 0.0481
# Epoch 41/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6600 - accuracy: 0.6250 - val_loss: 0.9950 - val_accuracy: 0.0481
# Epoch 42/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6599 - accuracy: 0.6238 - val_loss: 0.9524 - val_accuracy: 0.0480
# Epoch 43/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6599 - accuracy: 0.6236 - val_loss: 0.9067 - val_accuracy: 0.0481
# Epoch 44/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6602 - accuracy: 0.6236 - val_loss: 0.9867 - val_accuracy: 0.0481
# Epoch 45/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6601 - accuracy: 0.6243 - val_loss: 1.0052 - val_accuracy: 0.0469
# Epoch 46/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6598 - accuracy: 0.6244 - val_loss: 1.0104 - val_accuracy: 0.0470
# Epoch 47/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6602 - accuracy: 0.6239 - val_loss: 0.9749 - val_accuracy: 0.0453
# Epoch 48/50
# 6495/6495 [==============================] - 51s 8ms/step - loss: 0.6599 - accuracy: 0.6237 - val_loss: 1.0045 - val_accuracy: 0.0481
# Epoch 49/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6598 - accuracy: 0.6243 - val_loss: 1.0973 - val_accuracy: 0.0384
# Epoch 50/50
# 6495/6495 [==============================] - 52s 8ms/step - loss: 0.6601 - accuracy: 0.6242 - val_loss: 0.8996 - val_accuracy: 0.0481

# %%
model_tb.save('./demo/cnn_tb_bow_50.keras')

# %% [markdown]
# **<h1>MODEL EVALUATION</h1>**

# %%
df_test = pd.read_csv('./TRIPADVISOR_FOOD_SENTIMENTS_SARAWAK.csv', encoding='latin1', usecols=['Restaurant_Name', 'Review_Title', 'Caption'])
df_test.head(5)
# Out:
#   Restaurant_Name                       Review_Title  \
# 0       Balkanico  Lovely atmosphere and great pizza
# 1       Balkanico     Great food, relaxed atmosphere
# 2       Balkanico             Great thin crust pizza
# 3       Balkanico                Nice pizza and Tuak
# 4       Balkanico                          Excellent
#
#                                              Caption
# 0  Lovely atmosphere and great pizza We had a pep...
# 1  The food was delicious and the service good Ju...
# 2  This isnÃ¢ÂÂt really a restaurant more of a ...
# 3  The cafe is opposite a Chinese temle it is act...
# 4  I had the beef pepperoni pizza (25RM) with fri...

# %%
df_test_clean = df_test.dropna()
print(len(df_test_clean))
# Out:
# 1444

# %%
regex = r'[^a-zA-Z0-9\s]'

df_test_clean['Caption'] = df_test_clean['Caption'].str.replace(regex, '', regex=True)

# %%
df_test_clean['Caption'] = df_test_clean['Caption'].apply(lambda text: ''.join(c for c in text if c not in emoji.EMOJI_DATA))

# %%
df_test_clean['Caption'] = df_test_clean['Caption'].str.strip()
df_test_clean['Caption'] = df_test_clean['Caption'].str.lower()

# %%
df_test_clean['Vader_Label'] = df_test_clean['Caption'].apply(vader_sentiment)
df_test_clean['Afinn_Label'] = df_test_clean['Caption'].apply(afinn_sentiment)
df_test_clean['TextBlob_Label'] = df_test_clean['Caption'].apply(textblob_sentiment)

# %%
print(df_test_clean['TextBlob_Label'].value_counts())
print(df_test_clean['Vader_Label'].value_counts())
print(df_test_clean['Afinn_Label'].value_counts())
# Out:
# TextBlob_Label
# positive    1346
# negative      98
# Name: count, dtype: int64
# Vader_Label
# positive    1350
# negative      94
# Name: count, dtype: int64
# Afinn_Label
# positive    1377
# negative      67
# Name: count, dtype: int64

# %%
balanced_test_textblob = balance_sentiment(df_test_clean, 'TextBlob_Label', 'Caption')
balanced_test_vader = balance_sentiment(df_test_clean, 'Vader_Label', 'Caption')
balanced_test_afinn = balance_sentiment(df_test_clean, 'Afinn_Label', 'Caption')

# %%
print(balanced_test_textblob['TextBlob_Label'].value_counts())
print(balanced_test_vader['Vader_Label'].value_counts())
print(balanced_test_afinn['Afinn_Label'].value_counts())
# Out:
# TextBlob_Label
# positive    1346
# negative    1346
# Name: count, dtype: int64
# Vader_Label
# positive    1350
# negative    1350
# Name: count, dtype: int64
# Afinn_Label
# positive    1377
# negative    1377
# Name: count, dtype: int64

# %%
# Bag of Words
test_tb_bow = balanced_test_textblob['Caption'].astype(str).tolist()
test_vader_bow = balanced_test_vader['Caption'].astype(str).tolist()
test_afinn_bow = balanced_test_afinn['Caption'].astype(str).tolist()

# %%
X_test_tb_bow = vectorizer.fit_transform(test_tb_bow).toarray()
X_test_vader_bow = vectorizer.fit_transform(test_vader_bow).toarray()
X_test_afinn_bow = vectorizer.fit_transform(test_afinn_bow).toarray()

# %%
balanced_test_textblob['TextBlob_Label'] = balanced_test_textblob['TextBlob_Label'].replace({'positive': 1, 'negative': 0})
balanced_test_vader['Vader_Label'] = balanced_test_vader['Vader_Label'].replace({'positive': 1, 'negative': 0})
balanced_test_afinn['Afinn_Label'] = balanced_test_afinn['Afinn_Label'].replace({'positive': 1, 'negative': 0})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6624\1609484366.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balanced_test_textblob['TextBlob_Label'] = balanced_test_textblob['TextBlob_Label'].replace({'positive': 1, 'negative': 0})
# C:\Users\USER\AppData\Local\Temp\ipykernel_6624\1609484366.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balanced_test_vader['Vader_Label'] = balanced_test_vader['Vader_Label'].replace({'positive': 1, 'negative': 0})
# C:\Users\USER\AppData\Local\Temp\ipykernel_6624\1609484366.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balanced_test_afinn['Afinn_Label'] = balanced_test_afinn['Afinn_Label'].replace({'positive': 1, 'negative': 0})

# %%
y_test_tb_bow = LabelEncoder().fit_transform(balanced_test_textblob['TextBlob_Label'])
y_test_vader_bow = LabelEncoder().fit_transform(balanced_test_vader['Vader_Label'])
y_test_afinn_bow = LabelEncoder().fit_transform(balanced_test_afinn['Afinn_Label'])

# %%
X_test_tb_bow_seq = pad_sequences(X_test_tb_bow, maxlen=150, padding='post', truncating='post', value=0)
X_test_vader_bow_seq = pad_sequences(X_test_vader_bow, maxlen=150, padding='post', truncating='post', value=0)
X_test_afinn_bow_seq = pad_sequences(X_test_afinn_bow, maxlen=150, padding='post', truncating='post', value=0)

# %% [markdown]
# **<h3>CNN VADER EVALUATION</h3>**

# %%
loaded_model_vader = load_model('./demo/cnn_vader_bow_50.keras')

# %%
y_pred_proba_vader = loaded_model_vader.predict(X_test_vader_bow_seq)
y_pred_vader = (y_pred_proba_vader > 0.5).astype(int).flatten()
# Out:
# 85/85 [==============================] - 3s 2ms/step

# %%
f1 = f1_score(y_test_vader_bow, y_pred_vader, average='binary')
accuracy = accuracy_score(y_test_vader_bow, y_pred_vader)
precision =precision_score(y_test_vader_bow, y_pred_vader)
recall = recall_score(y_test_vader_bow, y_pred_vader)

loaded_model_vader = {
    'f1_score': f1,
    'accuracy': accuracy,
    'predictions': y_pred_vader,
    'precision': y_pred_vader,
    'recall': y_pred_vader,
    'true_labels': y_test_vader_bow
}

print('VADER Results:')
print('F1:', f1)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
# Out:
# VADER Results:
# F1: 0.6678235002478929
# Accuracy: 0.5037037037037037
# Precision: 0.5018628912071535
# Recall: 0.9977777777777778

# %% [markdown]
# **<h3>CNN AFINN EVALUATION</h3>**

# %%
loaded_model_afinn = load_model('./demo/cnn_afinn_bow_50.keras')

# %%
y_pred_proba_afinn = loaded_model_afinn.predict(X_test_afinn_bow_seq)
y_pred_afinn = (y_pred_proba_afinn > 0.5).astype(int).flatten()
# Out:
# 87/87 [==============================] - 0s 2ms/step

# %%
f1 = f1_score(y_test_afinn_bow, y_pred_afinn, average='binary')
accuracy = accuracy_score(y_test_afinn_bow, y_pred_afinn)
precision =precision_score(y_test_afinn_bow, y_pred_afinn)
recall = recall_score(y_test_afinn_bow, y_pred_afinn)

loaded_model_vader = {
    'f1_score': f1,
    'accuracy': accuracy,
    'predictions': y_pred_afinn,
    'precision': y_pred_afinn,
    'recall': y_pred_afinn,
    'true_labels': y_test_afinn_bow
}

print('AFINN Results:')
print('F1:', f1)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
# Out:
# AFINN Results:
# F1: 0.665374363944754
# Accuracy: 0.49854756717501814
# Precision: 0.49927272727272726
# Recall: 0.9970951343500363

# %% [markdown]
# **<h3>CNN TEXTBLOB EVALUATION</h3>**

# %%
loaded_model_tb = load_model('./demo/cnn_tb_bow_50.keras')

# %%
y_pred_proba_tb = loaded_model_tb.predict(X_test_tb_bow_seq)
y_pred_tb = (y_pred_proba_tb > 0.5).astype(int).flatten()
# Out:
# 85/85 [==============================] - 0s 2ms/step

# %%
f1 = f1_score(y_test_tb_bow, y_pred_tb, average='binary')
accuracy = accuracy_score(y_test_tb_bow, y_pred_tb)
precision =precision_score(y_test_tb_bow, y_pred_tb)
recall = recall_score(y_test_tb_bow, y_pred_tb)

loaded_model_vader = {
    'f1_score': f1,
    'accuracy': accuracy,
    'predictions': y_pred_tb,
    'precision': y_pred_tb,
    'recall': y_pred_tb,
    'true_labels': y_test_tb_bow
}

print('TextBlob Results:')
print('F1:', f1)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
# Out:
# TextBlob Results:
# F1: 0.6653445711452652
# Accuracy: 0.4985141158989599
# Precision: 0.4992559523809524
# Recall: 0.9970282317979198
